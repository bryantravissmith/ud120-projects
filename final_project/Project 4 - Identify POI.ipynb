# %% [markdown]
# #Udacity - NanoDegree - Project 4 - Identifying POI
#
# ##Project Goal
# The goal of this project is to develop and tune a supervised classification algorithm to identify persons of interest (POI) in the Enron scandal based on a combination of publically available Enron financial data and email records. The modest goals are to have recall and precision scores above 0.3.
#
# The compiled data set contains information for 144 people employed at Enron, a ‘Travel Agency in the Park’, and the total compensations for all of these sources. Additionally, the Udacity.com course designer created email features that give the total number of e-mails sent and received for each user, and the total number of emails sent to and receieved from a POI. Of the 144 people, 18 of them are labeled as POIs.
#
# Lets start by reading in the data;

# %%
import sys
import pickle
import numpy as np
import pandas as pd

#Load Udacity Tools for Testing Results
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit
from tester import test_classifier, dump_classifier_and_data

### Load the dictionary containing the dataset
data_dict = pickle.load(open("final_project_dataset.pkl", "r") )
data = pd.DataFrame.from_dict(data_dict)
#Remove Invalide Rows
data = data.drop(['TOTAL','THE TRAVEL AGENCY IN THE PARK'],axis=1)
data = data.transpose()
#Give Each Person their own row
data
# Out:
#                                bonus deferral_payments deferred_income  \
# ALLEN PHILLIP K              4175000           2869717        -3081055
# BADUM JAMES P                    NaN            178980             NaN
# BANNANTINE JAMES M               NaN               NaN           -5104
# BAXTER JOHN C                1200000           1295738        -1386055
# BAY FRANKLIN R                400000            260455         -201641
# BAZELIDES PHILIP J               NaN            684694             NaN
# BECK SALLY W                  700000               NaN             NaN
# BELDEN TIMOTHY N             5249999           2144013        -2334434
# BELFER ROBERT                    NaN           -102500             NaN
# BERBERIAN DAVID                  NaN               NaN             NaN
# BERGSIEKER RICHARD P          250000               NaN         -485813
# BHATNAGAR SANJAY                 NaN               NaN             NaN
# BIBI PHILIPPE A              1000000               NaN             NaN
# BLACHMAN JEREMY M             850000               NaN             NaN
# BLAKE JR. NORMAN P               NaN               NaN         -113784
# BOWEN JR RAYMOND M           1350000               NaN            -833
# BROWN MICHAEL                    NaN               NaN             NaN
# BUCHANAN HAROLD G             500000               NaN             NaN
# BUTTS ROBERT H                750000               NaN          -75000
# BUY RICHARD B                 900000            649584         -694862
# CALGER CHRISTOPHER F         1250000               NaN         -262500
# CARTER REBECCA C              300000               NaN         -159792
# CAUSEY RICHARD A             1000000               NaN         -235000
# CHAN RONNIE                      NaN               NaN          -98784
# CHRISTODOULOU DIOMEDES           NaN               NaN             NaN
# CLINE KENNETH W                  NaN               NaN             NaN
# COLWELL WESLEY               1200000             27610         -144062
# CORDES WILLIAM R                 NaN               NaN             NaN
# COX DAVID                     800000               NaN          -41250
# CUMBERLAND MICHAEL S          325000               NaN             NaN
# ...                              ...               ...             ...
# SAVAGE FRANK                     NaN               NaN         -121284
# SCRIMSHAW MATTHEW                NaN               NaN             NaN
# SHANKMAN JEFFREY A           2000000               NaN             NaN
# SHAPIRO RICHARD S             650000               NaN             NaN
# SHARP VICTORIA T              600000            187469             NaN
# SHELBY REX                    200000               NaN           -4167
# SHERRICK JEFFREY B               NaN               NaN             NaN
# SHERRIFF JOHN R              1500000               NaN             NaN
# SKILLING JEFFREY K           5600000               NaN             NaN
# STABLER FRANK                 500000               NaN             NaN
# SULLIVAN-SHAKLOVITZ COLLEEN   100000            181993             NaN
# SUNDE MARTIN                  700000               NaN             NaN
# TAYLOR MITCHELL S             600000            227449             NaN
# THORN TERENCE H                  NaN             16586             NaN
# TILNEY ELIZABETH A            300000               NaN         -575000
# UMANOFF ADAM S                788750               NaN             NaN
# URQUHART JOHN A                  NaN               NaN          -36666
# WAKEHAM JOHN                     NaN               NaN             NaN
# WALLS JR ROBERT H             850000               NaN             NaN
# WALTERS GARETH W                 NaN             53625             NaN
# WASAFF GEORGE                 325000            831299         -583325
# WESTFAHL RICHARD K               NaN               NaN          -10800
# WHALEY DAVID A                   NaN               NaN             NaN
# WHALLEY LAWRENCE G           3000000               NaN             NaN
# WHITE JR THOMAS E             450000               NaN             NaN
# WINOKUR JR. HERBERT S            NaN               NaN          -25000
# WODRASKA JOHN                    NaN               NaN             NaN
# WROBEL BRUCE                     NaN               NaN             NaN
# YEAGER F SCOTT                   NaN               NaN             NaN
# YEAP SOON                        NaN               NaN             NaN
#
#                             director_fees                     email_address  \
# ALLEN PHILLIP K                       NaN           phillip.allen@enron.com
# BADUM JAMES P                         NaN                               NaN
# BANNANTINE JAMES M                    NaN        james.bannantine@enron.com
# BAXTER JOHN C                         NaN                               NaN
# BAY FRANKLIN R                        NaN               frank.bay@enron.com
# BAZELIDES PHILIP J                    NaN                               NaN
# BECK SALLY W                          NaN              sally.beck@enron.com
# BELDEN TIMOTHY N                      NaN              tim.belden@enron.com
# BELFER ROBERT                        3285                               NaN
# BERBERIAN DAVID                       NaN         david.berberian@enron.com
# BERGSIEKER RICHARD P                  NaN         rick.bergsieker@enron.com
# BHATNAGAR SANJAY                   137864        sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                       NaN           philippe.bibi@enron.com
# BLACHMAN JEREMY M                     NaN         jeremy.blachman@enron.com
# BLAKE JR. NORMAN P                 113784                               NaN
# BOWEN JR RAYMOND M                    NaN           raymond.bowen@enron.com
# BROWN MICHAEL                         NaN           michael.brown@enron.com
# BUCHANAN HAROLD G                     NaN           john.buchanan@enron.com
# BUTTS ROBERT H                        NaN               bob.butts@enron.com
# BUY RICHARD B                         NaN                rick.buy@enron.com
# CALGER CHRISTOPHER F                  NaN      christopher.calger@enron.com
# CARTER REBECCA C                      NaN          rebecca.carter@enron.com
# CAUSEY RICHARD A                      NaN          richard.causey@enron.com
# CHAN RONNIE                         98784                               NaN
# CHRISTODOULOU DIOMEDES                NaN  diomedes.christodoulou@enron.com
# CLINE KENNETH W                       NaN                               NaN
# COLWELL WESLEY                        NaN             wes.colwell@enron.com
# CORDES WILLIAM R                      NaN             bill.cordes@enron.com
# COX DAVID                             NaN                chip.cox@enron.com
# CUMBERLAND MICHAEL S                  NaN                               NaN
# ...                                   ...                               ...
# SAVAGE FRANK                       125034                               NaN
# SCRIMSHAW MATTHEW                     NaN       matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                    NaN        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                     NaN         richard.shapiro@enron.com
# SHARP VICTORIA T                      NaN             vicki.sharp@enron.com
# SHELBY REX                            NaN              rex.shelby@enron.com
# SHERRICK JEFFREY B                    NaN        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                       NaN           john.sherriff@enron.com
# SKILLING JEFFREY K                    NaN           jeff.skilling@enron.com
# STABLER FRANK                         NaN           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN           NaN                               NaN
# SUNDE MARTIN                          NaN             marty.sunde@enron.com
# TAYLOR MITCHELL S                     NaN         mitchell.taylor@enron.com
# THORN TERENCE H                       NaN           terence.thorn@enron.com
# TILNEY ELIZABETH A                    NaN        elizabeth.tilney@enron.com
# UMANOFF ADAM S                        NaN            adam.umanoff@enron.com
# URQUHART JOHN A                     36666                               NaN
# WAKEHAM JOHN                       109298                               NaN
# WALLS JR ROBERT H                     NaN               rob.walls@enron.com
# WALTERS GARETH W                      NaN                               NaN
# WASAFF GEORGE                         NaN           george.wasaff@enron.com
# WESTFAHL RICHARD K                    NaN           dick.westfahl@enron.com
# WHALEY DAVID A                        NaN                               NaN
# WHALLEY LAWRENCE G                    NaN            greg.whalley@enron.com
# WHITE JR THOMAS E                     NaN            thomas.white@enron.com
# WINOKUR JR. HERBERT S              108579                               NaN
# WODRASKA JOHN                         NaN           john.wodraska@enron.com
# WROBEL BRUCE                          NaN                               NaN
# YEAGER F SCOTT                        NaN            scott.yeager@enron.com
# YEAP SOON                             NaN                               NaN
#
#                             exercised_stock_options expenses from_messages  \
# ALLEN PHILLIP K                             1729541    13868          2195
# BADUM JAMES P                                257817     3486           NaN
# BANNANTINE JAMES M                          4046157    56301            29
# BAXTER JOHN C                               6680544    11200           NaN
# BAY FRANKLIN R                                  NaN   129142           NaN
# BAZELIDES PHILIP J                          1599641      NaN           NaN
# BECK SALLY W                                    NaN    37172          4343
# BELDEN TIMOTHY N                             953136    17355           484
# BELFER ROBERT                                  3285      NaN           NaN
# BERBERIAN DAVID                             1624396    11892           NaN
# BERGSIEKER RICHARD P                            NaN    59175            59
# BHATNAGAR SANJAY                            2604490      NaN            29
# BIBI PHILIPPE A                             1465734    38559            40
# BLACHMAN JEREMY M                            765313    84208            14
# BLAKE JR. NORMAN P                              NaN     1279           NaN
# BOWEN JR RAYMOND M                              NaN    65907            27
# BROWN MICHAEL                                   NaN    49288            41
# BUCHANAN HAROLD G                            825464      600           125
# BUTTS ROBERT H                                  NaN     9410           NaN
# BUY RICHARD B                               2542813      NaN          1053
# CALGER CHRISTOPHER F                            NaN    35818           144
# CARTER REBECCA C                                NaN      NaN            15
# CAUSEY RICHARD A                                NaN    30674            49
# CHAN RONNIE                                     NaN      NaN           NaN
# CHRISTODOULOU DIOMEDES                      5127155      NaN           NaN
# CLINE KENNETH W                                 NaN      NaN           NaN
# COLWELL WESLEY                                  NaN    16514            40
# CORDES WILLIAM R                             651850      NaN            12
# COX DAVID                                    117551    27861            33
# CUMBERLAND MICHAEL S                            NaN    22344           NaN
# ...                                             ...      ...           ...
# SAVAGE FRANK                                    NaN      NaN           NaN
# SCRIMSHAW MATTHEW                            759557      NaN           NaN
# SHANKMAN JEFFREY A                          1441898   178979          2681
# SHAPIRO RICHARD S                            607837   137767          1215
# SHARP VICTORIA T                             281073   116337           136
# SHELBY REX                                  1624396    22884            39
# SHERRICK JEFFREY B                          1426469      NaN            25
# SHERRIFF JOHN R                             1835558      NaN            92
# SKILLING JEFFREY K                         19250000    29336           108
# STABLER FRANK                                   NaN    16514           NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                 1362375      NaN           NaN
# SUNDE MARTIN                                    NaN      NaN            38
# TAYLOR MITCHELL S                           3181250      NaN            29
# THORN TERENCE H                             4452476    46145            41
# TILNEY ELIZABETH A                           591250      NaN            19
# UMANOFF ADAM S                                  NaN    53122            18
# URQUHART JOHN A                                 NaN   228656           NaN
# WAKEHAM JOHN                                    NaN   103773           NaN
# WALLS JR ROBERT H                           4346544    50936           146
# WALTERS GARETH W                            1030329    33785           NaN
# WASAFF GEORGE                               1668260      NaN            30
# WESTFAHL RICHARD K                              NaN    51870           NaN
# WHALEY DAVID A                                98718      NaN           NaN
# WHALLEY LAWRENCE G                          3282960    57838           556
# WHITE JR THOMAS E                           1297049    81353           NaN
# WINOKUR JR. HERBERT S                           NaN     1413           NaN
# WODRASKA JOHN                                   NaN      NaN           NaN
# WROBEL BRUCE                                 139130      NaN           NaN
# YEAGER F SCOTT                              8308552    53947           NaN
# YEAP SOON                                    192758    55097           NaN
#
#                             from_poi_to_this_person from_this_person_to_poi  \
# ALLEN PHILLIP K                                  47                      65
# BADUM JAMES P                                   NaN                     NaN
# BANNANTINE JAMES M                               39                       0
# BAXTER JOHN C                                   NaN                     NaN
# BAY FRANKLIN R                                  NaN                     NaN
# BAZELIDES PHILIP J                              NaN                     NaN
# BECK SALLY W                                    144                     386
# BELDEN TIMOTHY N                                228                     108
# BELFER ROBERT                                   NaN                     NaN
# BERBERIAN DAVID                                 NaN                     NaN
# BERGSIEKER RICHARD P                              4                       0
# BHATNAGAR SANJAY                                  0                       1
# BIBI PHILIPPE A                                  23                       8
# BLACHMAN JEREMY M                                25                       2
# BLAKE JR. NORMAN P                              NaN                     NaN
# BOWEN JR RAYMOND M                              140                      15
# BROWN MICHAEL                                    13                       1
# BUCHANAN HAROLD G                                 0                       0
# BUTTS ROBERT H                                  NaN                     NaN
# BUY RICHARD B                                   156                      71
# CALGER CHRISTOPHER F                            199                      25
# CARTER REBECCA C                                 29                       7
# CAUSEY RICHARD A                                 58                      12
# CHAN RONNIE                                     NaN                     NaN
# CHRISTODOULOU DIOMEDES                          NaN                     NaN
# CLINE KENNETH W                                 NaN                     NaN
# COLWELL WESLEY                                  240                      11
# CORDES WILLIAM R                                 10                       0
# COX DAVID                                         0                       4
# CUMBERLAND MICHAEL S                            NaN                     NaN
# ...                                             ...                     ...
# SAVAGE FRANK                                    NaN                     NaN
# SCRIMSHAW MATTHEW                               NaN                     NaN
# SHANKMAN JEFFREY A                               94                      83
# SHAPIRO RICHARD S                                74                      65
# SHARP VICTORIA T                                 24                       6
# SHELBY REX                                       13                      14
# SHERRICK JEFFREY B                               39                      18
# SHERRIFF JOHN R                                  28                      23
# SKILLING JEFFREY K                               88                      30
# STABLER FRANK                                   NaN                     NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                     NaN                     NaN
# SUNDE MARTIN                                     37                      13
# TAYLOR MITCHELL S                                 0                       0
# THORN TERENCE H                                   0                       0
# TILNEY ELIZABETH A                               10                      11
# UMANOFF ADAM S                                   12                       0
# URQUHART JOHN A                                 NaN                     NaN
# WAKEHAM JOHN                                    NaN                     NaN
# WALLS JR ROBERT H                                17                       0
# WALTERS GARETH W                                NaN                     NaN
# WASAFF GEORGE                                    22                       7
# WESTFAHL RICHARD K                              NaN                     NaN
# WHALEY DAVID A                                  NaN                     NaN
# WHALLEY LAWRENCE G                              186                      24
# WHITE JR THOMAS E                               NaN                     NaN
# WINOKUR JR. HERBERT S                           NaN                     NaN
# WODRASKA JOHN                                   NaN                     NaN
# WROBEL BRUCE                                    NaN                     NaN
# YEAGER F SCOTT                                  NaN                     NaN
# YEAP SOON                                       NaN                     NaN
#
#                                    ...        long_term_incentive    other  \
# ALLEN PHILLIP K                    ...                     304805      152
# BADUM JAMES P                      ...                        NaN      NaN
# BANNANTINE JAMES M                 ...                        NaN   864523
# BAXTER JOHN C                      ...                    1586055  2660303
# BAY FRANKLIN R                     ...                        NaN       69
# BAZELIDES PHILIP J                 ...                      93750      874
# BECK SALLY W                       ...                        NaN      566
# BELDEN TIMOTHY N                   ...                        NaN   210698
# BELFER ROBERT                      ...                        NaN      NaN
# BERBERIAN DAVID                    ...                        NaN      NaN
# BERGSIEKER RICHARD P               ...                     180250   427316
# BHATNAGAR SANJAY                   ...                        NaN   137864
# BIBI PHILIPPE A                    ...                     369721   425688
# BLACHMAN JEREMY M                  ...                     831809      272
# BLAKE JR. NORMAN P                 ...                        NaN      NaN
# BOWEN JR RAYMOND M                 ...                     974293     1621
# BROWN MICHAEL                      ...                        NaN      NaN
# BUCHANAN HAROLD G                  ...                     304805     1215
# BUTTS ROBERT H                     ...                     175000   150656
# BUY RICHARD B                      ...                     769862   400572
# CALGER CHRISTOPHER F               ...                     375304      486
# CARTER REBECCA C                   ...                      75000      540
# CAUSEY RICHARD A                   ...                     350000   307895
# CHAN RONNIE                        ...                        NaN      NaN
# CHRISTODOULOU DIOMEDES             ...                        NaN      NaN
# CLINE KENNETH W                    ...                        NaN      NaN
# COLWELL WESLEY                     ...                        NaN   101740
# CORDES WILLIAM R                   ...                        NaN      NaN
# COX DAVID                          ...                        NaN      494
# CUMBERLAND MICHAEL S               ...                     275000      713
# ...                                ...                        ...      ...
# SAVAGE FRANK                       ...                        NaN      NaN
# SCRIMSHAW MATTHEW                  ...                        NaN      NaN
# SHANKMAN JEFFREY A                 ...                     554422     1191
# SHAPIRO RICHARD S                  ...                        NaN      705
# SHARP VICTORIA T                   ...                     422158     2401
# SHELBY REX                         ...                        NaN  1573324
# SHERRICK JEFFREY B                 ...                        NaN      NaN
# SHERRIFF JOHN R                    ...                     554422  1852186
# SKILLING JEFFREY K                 ...                    1920000    22122
# STABLER FRANK                      ...                        NaN   356071
# SULLIVAN-SHAKLOVITZ COLLEEN        ...                     554422      162
# SUNDE MARTIN                       ...                     476451   111122
# TAYLOR MITCHELL S                  ...                        NaN      NaN
# THORN TERENCE H                    ...                     200000   426629
# TILNEY ELIZABETH A                 ...                     275000   152055
# UMANOFF ADAM S                     ...                        NaN      NaN
# URQUHART JOHN A                    ...                        NaN      NaN
# WAKEHAM JOHN                       ...                        NaN      NaN
# WALLS JR ROBERT H                  ...                     540751        2
# WALTERS GARETH W                   ...                        NaN      NaN
# WASAFF GEORGE                      ...                     200000     1425
# WESTFAHL RICHARD K                 ...                     256191   401130
# WHALEY DAVID A                     ...                        NaN      NaN
# WHALLEY LAWRENCE G                 ...                     808346   301026
# WHITE JR THOMAS E                  ...                        NaN  1085463
# WINOKUR JR. HERBERT S              ...                        NaN      NaN
# WODRASKA JOHN                      ...                        NaN   189583
# WROBEL BRUCE                       ...                        NaN      NaN
# YEAGER F SCOTT                     ...                        NaN   147950
# YEAP SOON                          ...                        NaN      NaN
#
#                                poi restricted_stock restricted_stock_deferred  \
# ALLEN PHILLIP K              False           126027                   -126027
# BADUM JAMES P                False              NaN                       NaN
# BANNANTINE JAMES M           False          1757552                   -560222
# BAXTER JOHN C                False          3942714                       NaN
# BAY FRANKLIN R               False           145796                    -82782
# BAZELIDES PHILIP J           False              NaN                       NaN
# BECK SALLY W                 False           126027                       NaN
# BELDEN TIMOTHY N              True           157569                       NaN
# BELFER ROBERT                False              NaN                     44093
# BERBERIAN DAVID              False           869220                       NaN
# BERGSIEKER RICHARD P         False           659249                       NaN
# BHATNAGAR SANJAY             False         -2604490                  15456290
# BIBI PHILIPPE A              False           378082                       NaN
# BLACHMAN JEREMY M            False           189041                       NaN
# BLAKE JR. NORMAN P           False              NaN                       NaN
# BOWEN JR RAYMOND M            True           252055                       NaN
# BROWN MICHAEL                False              NaN                       NaN
# BUCHANAN HAROLD G            False           189041                       NaN
# BUTTS ROBERT H               False           417619                       NaN
# BUY RICHARD B                False           901657                       NaN
# CALGER CHRISTOPHER F          True           126027                       NaN
# CARTER REBECCA C             False           307301                   -307301
# CAUSEY RICHARD A              True          2502063                       NaN
# CHAN RONNIE                  False            32460                    -32460
# CHRISTODOULOU DIOMEDES       False           950730                       NaN
# CLINE KENNETH W              False           662086                   -472568
# COLWELL WESLEY                True           698242                       NaN
# CORDES WILLIAM R             False           386335                       NaN
# COX DAVID                    False           378082                       NaN
# CUMBERLAND MICHAEL S         False           207940                       NaN
# ...                            ...              ...                       ...
# SAVAGE FRANK                 False              NaN                       NaN
# SCRIMSHAW MATTHEW            False              NaN                       NaN
# SHANKMAN JEFFREY A           False           630137                       NaN
# SHAPIRO RICHARD S            False           379164                       NaN
# SHARP VICTORIA T             False           213063                       NaN
# SHELBY REX                    True           869220                       NaN
# SHERRICK JEFFREY B           False           405999                       NaN
# SHERRIFF JOHN R              False          1293424                       NaN
# SKILLING JEFFREY K            True          6843672                       NaN
# STABLER FRANK                False           511734                       NaN
# SULLIVAN-SHAKLOVITZ COLLEEN  False              NaN                       NaN
# SUNDE MARTIN                 False           698920                       NaN
# TAYLOR MITCHELL S            False           563798                       NaN
# THORN TERENCE H              False           365320                       NaN
# TILNEY ELIZABETH A           False           576792                       NaN
# UMANOFF ADAM S               False              NaN                       NaN
# URQUHART JOHN A              False              NaN                       NaN
# WAKEHAM JOHN                 False              NaN                       NaN
# WALLS JR ROBERT H            False          1552453                       NaN
# WALTERS GARETH W             False              NaN                       NaN
# WASAFF GEORGE                False           388167                       NaN
# WESTFAHL RICHARD K           False           384930                       NaN
# WHALEY DAVID A               False              NaN                       NaN
# WHALLEY LAWRENCE G           False          2796177                       NaN
# WHITE JR THOMAS E            False         13847074                       NaN
# WINOKUR JR. HERBERT S        False              NaN                       NaN
# WODRASKA JOHN                False              NaN                       NaN
# WROBEL BRUCE                 False              NaN                       NaN
# YEAGER F SCOTT                True          3576206                       NaN
# YEAP SOON                    False              NaN                       NaN
#
#                               salary shared_receipt_with_poi to_messages  \
# ALLEN PHILLIP K               201955                    1407        2902
# BADUM JAMES P                    NaN                     NaN         NaN
# BANNANTINE JAMES M               477                     465         566
# BAXTER JOHN C                 267102                     NaN         NaN
# BAY FRANKLIN R                239671                     NaN         NaN
# BAZELIDES PHILIP J             80818                     NaN         NaN
# BECK SALLY W                  231330                    2639        7315
# BELDEN TIMOTHY N              213999                    5521        7991
# BELFER ROBERT                    NaN                     NaN         NaN
# BERBERIAN DAVID               216582                     NaN         NaN
# BERGSIEKER RICHARD P          187922                     233         383
# BHATNAGAR SANJAY                 NaN                     463         523
# BIBI PHILIPPE A               213625                    1336        1607
# BLACHMAN JEREMY M             248546                    2326        2475
# BLAKE JR. NORMAN P               NaN                     NaN         NaN
# BOWEN JR RAYMOND M            278601                    1593        1858
# BROWN MICHAEL                    NaN                     761        1486
# BUCHANAN HAROLD G             248017                      23        1088
# BUTTS ROBERT H                261516                     NaN         NaN
# BUY RICHARD B                 330546                    2333        3523
# CALGER CHRISTOPHER F          240189                    2188        2598
# CARTER REBECCA C              261809                     196         312
# CAUSEY RICHARD A              415189                    1585        1892
# CHAN RONNIE                      NaN                     NaN         NaN
# CHRISTODOULOU DIOMEDES           NaN                     NaN         NaN
# CLINE KENNETH W                  NaN                     NaN         NaN
# COLWELL WESLEY                288542                    1132        1758
# CORDES WILLIAM R                 NaN                      58         764
# COX DAVID                     314288                      71         102
# CUMBERLAND MICHAEL S          184899                     NaN         NaN
# ...                              ...                     ...         ...
# SAVAGE FRANK                     NaN                     NaN         NaN
# SCRIMSHAW MATTHEW                NaN                     NaN         NaN
# SHANKMAN JEFFREY A            304110                    1730        3221
# SHAPIRO RICHARD S             269076                    4527       15149
# SHARP VICTORIA T              248146                    2477        3136
# SHELBY REX                    211844                      91         225
# SHERRICK JEFFREY B               NaN                     583         613
# SHERRIFF JOHN R               428780                    2103        3187
# SKILLING JEFFREY K           1111258                    2042        3627
# STABLER FRANK                 239502                     NaN         NaN
# SULLIVAN-SHAKLOVITZ COLLEEN   162779                     NaN         NaN
# SUNDE MARTIN                  257486                    2565        2647
# TAYLOR MITCHELL S             265214                     300         533
# THORN TERENCE H               222093                      73         266
# TILNEY ELIZABETH A            247338                     379         460
# UMANOFF ADAM S                288589                      41         111
# URQUHART JOHN A                  NaN                     NaN         NaN
# WAKEHAM JOHN                     NaN                     NaN         NaN
# WALLS JR ROBERT H             357091                     215         671
# WALTERS GARETH W                 NaN                     NaN         NaN
# WASAFF GEORGE                 259996                     337         400
# WESTFAHL RICHARD K             63744                     NaN         NaN
# WHALEY DAVID A                   NaN                     NaN         NaN
# WHALLEY LAWRENCE G            510364                    3920        6019
# WHITE JR THOMAS E             317543                     NaN         NaN
# WINOKUR JR. HERBERT S            NaN                     NaN         NaN
# WODRASKA JOHN                    NaN                     NaN         NaN
# WROBEL BRUCE                     NaN                     NaN         NaN
# YEAGER F SCOTT                158403                     NaN         NaN
# YEAP SOON                        NaN                     NaN         NaN
#
#                             total_payments total_stock_value
# ALLEN PHILLIP K                    4484442           1729541
# BADUM JAMES P                       182466            257817
# BANNANTINE JAMES M                  916197           5243487
# BAXTER JOHN C                      5634343          10623258
# BAY FRANKLIN R                      827696             63014
# BAZELIDES PHILIP J                  860136           1599641
# BECK SALLY W                        969068            126027
# BELDEN TIMOTHY N                   5501630           1110705
# BELFER ROBERT                       102500            -44093
# BERBERIAN DAVID                     228474           2493616
# BERGSIEKER RICHARD P                618850            659249
# BHATNAGAR SANJAY                  15456290               NaN
# BIBI PHILIPPE A                    2047593           1843816
# BLACHMAN JEREMY M                  2014835            954354
# BLAKE JR. NORMAN P                    1279               NaN
# BOWEN JR RAYMOND M                 2669589            252055
# BROWN MICHAEL                        49288               NaN
# BUCHANAN HAROLD G                  1054637           1014505
# BUTTS ROBERT H                     1271582            417619
# BUY RICHARD B                      2355702           3444470
# CALGER CHRISTOPHER F               1639297            126027
# CARTER REBECCA C                    477557               NaN
# CAUSEY RICHARD A                   1868758           2502063
# CHAN RONNIE                            NaN               NaN
# CHRISTODOULOU DIOMEDES                 NaN           6077885
# CLINE KENNETH W                        NaN            189518
# COLWELL WESLEY                     1490344            698242
# CORDES WILLIAM R                       NaN           1038185
# COX DAVID                          1101393            495633
# CUMBERLAND MICHAEL S                807956            207940
# ...                                    ...               ...
# SAVAGE FRANK                          3750               NaN
# SCRIMSHAW MATTHEW                      NaN            759557
# SHANKMAN JEFFREY A                 3038702           2072035
# SHAPIRO RICHARD S                  1057548            987001
# SHARP VICTORIA T                   1576511            494136
# SHELBY REX                         2003885           2493616
# SHERRICK JEFFREY B                     NaN           1832468
# SHERRIFF JOHN R                    4335388           3128982
# SKILLING JEFFREY K                 8682716          26093672
# STABLER FRANK                      1112087            511734
# SULLIVAN-SHAKLOVITZ COLLEEN         999356           1362375
# SUNDE MARTIN                       1545059            698920
# TAYLOR MITCHELL S                  1092663           3745048
# THORN TERENCE H                     911453           4817796
# TILNEY ELIZABETH A                  399393           1168042
# UMANOFF ADAM S                     1130461               NaN
# URQUHART JOHN A                     228656               NaN
# WAKEHAM JOHN                        213071               NaN
# WALLS JR ROBERT H                  1798780           5898997
# WALTERS GARETH W                     87410           1030329
# WASAFF GEORGE                      1034395           2056427
# WESTFAHL RICHARD K                  762135            384930
# WHALEY DAVID A                         NaN             98718
# WHALLEY LAWRENCE G                 4677574           6079137
# WHITE JR THOMAS E                  1934359          15144123
# WINOKUR JR. HERBERT S                84992               NaN
# WODRASKA JOHN                       189583               NaN
# WROBEL BRUCE                           NaN            139130
# YEAGER F SCOTT                      360300          11884758
# YEAP SOON                            55097            192758
#
# [144 rows x 21 columns]

# %% [markdown]
# In regards to the financial information, I defined outliers as having values that are more than 3 standard deviations from the mean value for the group. This is not the traditional definition or criteria for an outlier which is 1.5 times the interquartile range below the first quartile or Above the third quartile. I used my definition after I have replaced missing values with zero. Using this definition of outliers there are 25 people in the data set that are financial outliers:

# %%
finance = ['salary',
             'deferral_payments',
             'total_payments',
             'exercised_stock_options',
             'bonus',
             'restricted_stock',
             'restricted_stock_deferred',
             'total_stock_value',
             'expenses',
             'loan_advances',
             'other',
             'director_fees',
             'deferred_income',
             'long_term_incentive']

from scipy import stats
#Use unique because some people are financial outliers in multiple variables
data[np.abs(stats.zscore(data[finance].replace('NaN',0.0))) > 3].index.unique()
# Out:
# array(['ALLEN PHILLIP K', 'BELDEN TIMOTHY N', 'BHATNAGAR SANJAY',
#        'BLAKE JR. NORMAN P', 'FREVERT MARK A', 'GRAMM WENDY L',
#        'HANNON KEVIN P', 'HIRKO JOSEPH', 'HORTON STANLEY C',
#        'HUMPHREY GENE E', 'JAEDICKE ROBERT', 'LAVORATO JOHN J',
#        'LAY KENNETH L', 'LEMAISTRE CHARLES', 'MARTIN AMANDA K',
#        'MCCLELLAN GEORGE', 'MENDELSOHN JOHN', 'PAI LOU L',
#        'RICE KENNETH D', 'SAVAGE FRANK', 'SHANKMAN JEFFREY A',
#        'SKILLING JEFFREY K', 'URQUHART JOHN A', 'WAKEHAM JOHN',
#        'WHITE JR THOMAS E', 'WINOKUR JR. HERBERT S'], dtype=object)

# %% [markdown]
# This accounts for 17% of the data being considered an outlier and also contains 33% of the POI. Ultimately I decided that financial outliers were relevant information, and decided not to remove them from the data for this analysis.
#
# ##New Feature
#
# I decided to create two features I thought were be informative to the data: the ratio of emails received from a POI to the total number of emails received and the ratio of emails sent to a POI to the total number of emails sent.
# I thought these features would be more informative than the total number of emails sent or received from a POI because it normalizes by how active or how popular a person is.
#
# If a person sends 10 emails, and 5 of them are to a POI, that seems more relevant than if a person sends 1000 emails and 5 of them are to a POI. A person who sends 50% of their emails to a person of interest seems more suspect than a person who only sends 0.5% of their emails to a POI.
#
# The inverse is not true, however. If a person received 10 emails from a POI, that is as relevant regardless if the person receives 20 emails or 2000 emails. The important idea is that how often is a POI is contacting this person, and how does that affect the likelihood that a person is also a POI. This ratio does not capture that idea, but I created it because I was willing to be proven wrong.

# %%
data.from_this_person_to_poi = data.from_this_person_to_poi.astype(float)
data.from_poi_to_this_person = data.from_poi_to_this_person.astype(float)
data.to_messages = data.to_messages.astype(float)
data.from_messages = data.from_messages.astype(float)
data['from_this_person_to_poi_ratio'] = data.from_this_person_to_poi/data.to_messages
data['from_poi_to_this_person_ratio'] = data.from_poi_to_this_person/data.from_messages
data = data.replace('NaN',0.0)

# %% [markdown]
# After the creation of these features I used sklearn's Pipeline, FeatureUnion, and GridSearch to search through a combintation of variable to find the set of features that gave the best performance for a Decision Tree Classifier.  I search between 1 and 9 of the best features using a 5 folds stratified cross validation to gauge performance for each set.  I am using a f1 score to maximize the weight combintation of recall and precision.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.grid_search import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve
from sklearn.learning_curve import learning_curve

tru = data.poi.values
trn = data.drop(['poi','email_address'],axis=1).values
clf = DecisionTreeClassifier()

#pca = PCA(n_components=2)
selection = SelectKBest(k=1)
#combined_features = FeatureUnion([("pca", pca), ("univ_select", selection)])
combined_features = FeatureUnion([("univ_select", selection)])

X_features = combined_features.fit(trn, tru).transform(trn)

pipeline = Pipeline([("features", combined_features), ("clf", clf)])

#param_grid = dict(features__pca__n_components=range(0,15),
#                  features__univ_select__k=range(1,10))

param_grid = dict(features__univ_select__k=range(1,10))

skf = StratifiedKFold(tru, n_folds=5)
grid_search = GridSearchCV(pipeline, cv=skf, param_grid=param_grid, scoring='f1')
grid_search.fit(trn, tru)
print grid_search.best_score_
print grid_search.best_params_
var_scores = grid_search.best_estimator_.steps[0][1].get_params()['univ_select'].scores_
print var_scores
num_features = grid_search.best_params_['features__univ_select__k']
best_features = data.drop(['poi','email_address'],axis=1).columns[np.argsort(var_scores)[::-1][:num_features]]
best_features
# Out:
# 0.36813973064
# {'features__univ_select__k': 3}
# [ 21.06000171   0.21705893  11.59554766   2.10765594  25.09754153
#    6.23420114   0.1641645    5.34494152   2.42650813   7.2427304
#   10.07245453   4.24615354   9.34670079   0.06498431  18.57570327
#    8.74648553   1.69882435   8.87383526  24.46765405   4.16908382
#    5.20965022]
# Index([u'exercised_stock_options', u'total_stock_value', u'bonus'], dtype='object')

# %% [markdown]
# ##Result of Search
#
# The search is finished and the best f1 score of 0.368 with 3 'best features'.  Because of the random shuffling involved in the scoring, it is possible to get a variety in number and combintations of best features.
#
# The best features for predicting if a person is a person of interest are financal features: Exercised stock options, total stock value, and bonus.  Even when the number of best features fluxuate, these 3 are always among them.
#
# ##Turning Model
# Using the paramemters from the above search we will now tune the classifier to optimize its performance. I am searching through the spliting and depth criteria for the Decision Tree Classifier.

# %%
tru = data.poi.values
trn = data[best_features].values
clf = DecisionTreeClassifier()
pipeline = Pipeline([("clf", clf)])

param_grid = dict(clf__criterion=("gini","entropy"),
                  clf__min_samples_split=[1,2,4,8,16,32],
                   clf__min_samples_leaf=[1,2,4,8,16,32],
                   clf__max_depth=[None,1,2,4,8,16,32])

skf = StratifiedKFold(tru, n_folds=5)
grid_search = GridSearchCV(pipeline, cv=skf, param_grid=param_grid, scoring='f1')
grid_search.fit(trn, tru)
print grid_search.best_params_
print grid_search.best_score_
best_clf = grid_search.best_estimator_
best_clf
# Out:
# {'clf__criterion': 'gini', 'clf__max_depth': 32, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 1}
# 0.47075617284
# Pipeline(steps=[('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=32,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=1, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best'))])

# %% [markdown]
# The best parameters for the Decision Tree Classifier has a max depth of 32, a min sample leaf size of 1, and requires at least 1 values to split the tree when fitting.  These results produced the best averge f1 score of 0.47.
#
# ##Importance of Validation
#
# Validation is an attempt to confirm that a model will give reasonable or consistent results on new, untrained data. A classic mistake is to test the results of a model on the data used to train the model. This is no doubt give the best possible score, but can over fit the data leading to less than desired results on new data. Validation protects against this mistake by training the model on one set of data and testing on yet another.
#
# I used 5-Fold Statfied Cross Validation for investigating and comparing algorithms in this analysis. This is where there the algorithm is trained on the on the data 5 times using 80% of the data as a training set and 20% of the data as a testing set.  Each set has approxiamately the same ratio of positive and negative examples of POI.  Each time this is done, the training and testing set are shuffled to create a new 80/20 split on the data. I then used the average performance as an estimate of its performance on new data.
#
# ## Final Performance
#
# Using the Udacity 'test_classifier' function I evaluate my classifer to see if the recall and precision scores are both greater than 0.3.

# %%
#tt = pd.DataFrame(pca.fit_transform(trn),index=data.index)
#data2 = data.join(tt)
#print data2.columns
my_data = data.transpose().to_dict()
features =  best_features.tolist()
features = ['poi']+features
test_classifier(best_clf, my_data, features)
# Out:
# Pipeline(steps=[('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=32,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=1, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best'))])
# 	Accuracy: 0.80492	Precision: 0.37066	Recall: 0.38400	F1: 0.37721	F2: 0.38125
# 	Total predictions: 13000	True positives:  768	False positives: 1304	False negatives: 1232	True negatives: 9696

# %% [markdown]
# The results of the tuned classifier are shown above.   The average precision of the 13000 prediction is 37% and the average recall is 38%.   The precision value is that out of all predictions of people being a POI, 38% of them are actually POI.  The recall value is that out of all of the POI, 37% are actually predicted to be POI by my tuned classifier.
